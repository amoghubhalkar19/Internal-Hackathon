# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("train.txt")
result_flat=pd.read_csv("flattened.csv", index_col=0)

# %%
df.head(22)

# %%
col_names=["id"]+["timestamp"]+[f's{i}' for i in range(1, 26)]
row_1=df.columns
row_1=pd.DataFrame(row_1.T)

# %%
df.columns=col_names

# %%
df.head()

# %%
new_df=pd.DataFrame(columns=df.columns)

# %%
new_df.head()

# %%
row_1=row_1.T

# %%
row_1.columns=col_names

# %%
row_1.head()

# %%
result = pd.concat([new_df, row_1], ignore_index=True)

# %%
result.head()
# Out:
#   id timestamp      s1      s2      s3      s4      s5      s6      s7  \
# 0  0         1  0.4337  0.7431  0.9390  0.7541  0.9035  0.7943  0.2622
#
#        s8  ...     s16     s17     s18     s19     s20     s21     s22  \
# 0  0.5901  ...  0.5696  0.6407  0.7027  0.7163  0.9954  0.8303  0.1641
#
#       s23     s24     s25
# 0  0.7893  0.7533  0.2925
#
# [1 rows x 27 columns]

# %%
result=pd.concat([result, df], ignore_index=True)

# %%
result.head(11)
# Out:
#    id timestamp      s1      s2      s3      s4      s5      s6      s7  \
# 0   0         1  0.4337  0.7431  0.9390  0.7541  0.9035  0.7943  0.2622
# 1   0       2.0  0.7859  0.1925  0.9024  0.8108  0.2016  0.9649  0.2445
# 2   0       3.0  0.0512  0.9633  0.1423  0.8404  0.6654  0.4348  0.5751
# 3   0       4.0  0.0413  0.1588  0.1675  0.0971  0.2918   0.197  0.0971
# 4   0       5.0  0.7042  0.4724  0.3901  0.2793  0.2522  0.1933  0.2694
# 5   0       6.0  0.9538  0.3029  0.4227  0.7774  0.5194  0.7531  0.4816
# 6   0       7.0  0.6729  0.9906  0.8604  0.2969  0.8278   0.484  0.2507
# 7   0       8.0  0.3945  0.4753   0.642  0.9227  0.8885  0.1002  0.5443
# 8   0       9.0  0.7368  0.8174   0.875   0.123   0.397  0.7676  0.5175
# 9   0      10.0  0.6752  0.1698  0.6974  0.1273   0.509  0.3354  0.8128
# 10  1       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#         s8  ...     s16     s17     s18     s19     s20     s21     s22  \
# ...

# %%
result.shape
result.info()

# %%
result['state']=0

# %%
result.loc[result['timestamp'].isnull(), 'state'] = result['id']
# Out:
# C:\Users\ubhal\AppData\Local\Temp\ipykernel_9444\453649395.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1 2 3 ... 1 0 1]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   result.loc[result['timestamp'].isnull(), 'state'] = result['id']

# %%
non_zero_indices = result[result['state'] != 0].index

for index in non_zero_indices:
    start_index = max(0, index - 10)
    end_index = index
    result.loc[start_index:end_index - 1, 'state'] = result.loc[index, 'state']

# %%
result.head(22)

# %%
# result=result.dropna()

# %%
# result.head(22)

# %%
# result.isnull().sum()
# result.shape

# %%
result_flat['state']=0
result_flat.head(10)

# %%
for i in range(9, 50000, 10):
 j=(i+1)/10 
 result_flat['state'][j]=result['id'][j]

# %%
result_flat.head(11)
# Out:
#          0       1       2       3       4       5       6       7       8  \
# 0   0.4337  0.7431  0.9390  0.7541  0.9035  0.7943  0.2622  0.5901  0.7558
# 1   0.4013  0.6779  0.9426  0.3566  0.3919  0.0981  0.9805  0.5617  0.7954
# 2   0.8912  0.4076  0.8245  0.7026  0.7784  0.4193  0.0786  0.0406  0.9235
# 3   0.4849  0.8162  0.7418  0.1640  0.0961  0.4293  0.2342  0.8210  0.3728
# 4   0.2426  0.3405  0.9523  0.4741  0.9078  0.7081  0.7006  0.5678  0.4405
# 5   0.8940  0.7624  0.0523  0.0107  0.8000  0.5953  0.4242  0.4626  0.5010
# 6   0.6487  0.7998  0.2444  0.5807  0.0921  0.2567  0.2635  0.8436  0.8573
# 7   0.3983  0.6386  0.9601  0.0522  0.0908  0.8874  0.2367  0.5091  0.6788
# 8   0.7677  0.7785  0.5903  0.1769  0.8166  0.6739  0.9283  0.9965  0.6701
# 9   0.9028  0.8775  0.5123  0.0746  0.1430  0.7986  0.0784  0.2497  0.4499
# 10  0.8147  0.8188  0.9058  0.3807  0.4672  0.5436  0.1798  0.7912  0.3474
#
# ...

# %%
# plt.figure(figsize=(20, 20))
# sns.scatterplot(x=result[result['timestamp']==2]['id'], y=result[result['timestamp']==2]['s1'], hue=result[result['timestamp']==2]['state'], palette=['red', 'green', 'blue', 'orange'])

# %%
# plt.figure(figsize=(5, 5))
# sns.lineplot(result[result['timestamp']==10]['s1'])
# #mean variance plot
# #

# %%
# numeric_columns = ['timestamp', 's1', 's2', 's3', 's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's20', 's21', 's22', 's23', 's24', 's25']
# result[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# %%
# X=result.drop(columns=['state', 'id'], axis=1)
# Y=result['state']

# %%
# from sklearn.model_selection import train_test_split
# x_train=X.iloc[:400000]
# x_test=X.iloc[400000:]
# y_train=Y.iloc[:400000]
# y_test=Y.iloc[400000:]

# %%
# import pandas as pd
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
# import xgboost as xgb

# # Initialize and train the model
# model = xgb.XGBClassifier()
# model.fit(x_train, y_train)

# # Make predictions
# y_pred = model.predict(x_test)
# seen_classes = set(y_test.unique())
# y_pred_filtered = [pred if pred in seen_classes else 'Unknown' for pred in y_pred]

# # Evaluate the model
# acc = accuracy_score(y_test, y_pred_filtered)
# print("Accuracy:", acc)
